# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
file="loss.txt"
data = np.loadtxt(file)
ep = data[:,0]
val_loss = data[:,1]
correct = data[:,2]

plt.clf()
fig = plt.figure(dpi=100)
# plt.plot(ep,val_loss, label="val_loss")
plt.plot(ep,correct, label="correct(%)")

plt.legend()
plt.xlabel("epoch")
plt.show()
